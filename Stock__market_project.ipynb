# %%
# !pip install yfinance
#!pip install pandas
# Out:
# ...
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/f8/2a/0f/4b5a86e1d52e451757eb6bc17fd899629f0925c777741b6d04
# ...
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/37/fa/73/d492849e319038eb4d986f5152e4b19ffb1bc0639da84d2677
# Successfully built yfinance multitasking
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
# Using the yfinance Library to Extract Stock Data

# %%
apple = yf.Ticker("AAPL")

# %%
# Stock Info

# %%
apple_info=apple.info
apple_info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
# Get the 'country'

# %%
apple_info['country']
# Out:
# 'United States'

# %% [markdown]
# # Extracting Share Price
# A share is the single smallest part of a company's stock that you can buy, the prices of these shares fluctuate over time. Using the history() method we can get the share price of the stock over a certain period of time. Using the period parameter we can set how far back from the present to get data. The options for period are 1 day (1d), 5d, 1 month (1mo) , 3mo, 6mo, 1 year (1y), 2y, 5y, 10y, ytd, and max.

# %%
apple_share_price_data = apple.history(period="max")

# %%
# The format that the data is returned in is a Pandas DataFrame. With the Date as the index the share Open, High, Low, Close, Volume, and Stock Splits are given for each day.

# %%
apple_share_price_data.head()
# Out:
#                 Open      High       Low     Close     Volume  Dividends  \
# Date
# 1980-12-12  0.100922  0.101361  0.100922  0.100922  469033600        0.0
# 1980-12-15  0.096096  0.096096  0.095657  0.095657  175884800        0.0
# 1980-12-16  0.089075  0.089075  0.088636  0.088636  105728000        0.0
# 1980-12-17  0.090830  0.091268  0.090830  0.090830   86441600        0.0
# 1980-12-18  0.093463  0.093902  0.093463  0.093463   73449600        0.0
#
#             Stock Splits
# Date
# 1980-12-12           0.0
# 1980-12-15           0.0
# 1980-12-16           0.0
# 1980-12-17           0.0
# 1980-12-18           0.0

# %%
# Reset the index of the DataFrame with the reset_index function. We also set the inplace paramter to True so the change takes place to the DataFrame itself.

# %%
apple_share_price_data.reset_index(inplace=True)

# %%
# Plot the Open price against the Date:

# %%
apple_share_price_data.plot(x="Date", y="Open")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Extracting Dividends

# %%
apple.dividends
# Out:
# Date
# 1987-05-11    0.000536
# 1987-08-10    0.000536
# 1987-11-17    0.000714
# 1988-02-12    0.000714
# 1988-05-16    0.000714
#                 ...
# 2020-02-07    0.192500
# 2020-05-08    0.205000
# 2020-08-07    0.205000
# 2020-11-06    0.205000
# 2021-02-05    0.205000
# Name: Dividends, Length: 70, dtype: float64

# %%
# plot the dividends overtime:

# %%
apple.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Practice exercises

# %%
amd = yf.Ticker("AMD")

# %%
amd_info = amd.info
amd.info
# Out:
# {'zip': '95054',
#  'sector': 'Technology',
#  'fullTimeEmployees': 12600,
# ...

# %%
# To find the country of the stock

# %%
amd_info['country']
# Out:
# 'United States'

# %%
# To find the sector of the stock

# %%
tickerdata = yf.Ticker('amd')
print (tickerdata.info['sector'])
# Out:
# Technology

# %%
# Find the max of the Volume column of AMD using the history function, set the period to max

# %%
amd_share_price_data = amd.history(period="max")

# %%
amd_share_price_data.head()
# Out:
#             Open      High       Low     Close  Volume  Dividends  \
# Date
# 1980-03-17   0.0  3.302083  3.125000  3.145833  219600          0
# 1980-03-18   0.0  3.125000  2.937500  3.031250  727200          0
# 1980-03-19   0.0  3.083333  3.020833  3.041667  295200          0
# 1980-03-20   0.0  3.062500  3.010417  3.010417  159600          0
# 1980-03-21   0.0  3.020833  2.906250  2.916667  130800          0
#
#             Stock Splits
# Date
# 1980-03-17           0.0
# 1980-03-18           0.0
# 1980-03-19           0.0
# 1980-03-20           0.0
# 1980-03-21           0.0

# %%
amd_share_price_data = amd.history(period="min")

# %%
amd_share_price_data.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-05-05  79.050003  79.300003  78.129997  78.490097  10080172          0
#
#             Stock Splits
# Date
# 2021-05-05             0
